# %% [markdown]
# <a href="https://colab.research.google.com/github/tishkosalam/bisection-method-assignment/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv("Titanic.csv")

# %%
mydata.head(5)
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
mydata.tail(5)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch   fare embarked  \
# 886         886         0       2    male  27.0      0      0  13.00        S
# 887         887         1       1  female  19.0      0      0  30.00        S
# 888         888         0       3  female   NaN      1      2  23.45        S
# 889         889         1       1    male  26.0      0      0  30.00        C
# 890         890         0       3    male  32.0      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
mydata.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x = "sex",y = "age", data = mydata)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
mydata['age'].std()
# Out:
# 14.526497332334044

# %%
mydata['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
sns.displot(mydata['age'])

# %%
corr = mydata.corr(numeric_only=True)
corr['survived']
# Out:
# Unnamed: 0   -0.005007
# survived      1.000000
# pclass       -0.338481
# age          -0.077221
# sibsp        -0.035322
# parch         0.081629
# fare          0.257307
# adult_male   -0.557080
# alone        -0.203367
# Name: survived, dtype: float64

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(mydata)

# %%
import scipy.stats as st

# %%
np.random.seed(42)

# %%
x = st.skewnorm.rvs(10, size=1000)

# %%
x[0:20]
# Out:
# array([0.86166144, 0.22941296, 0.82964258, 0.11860123, 1.82883791,
#        0.07934979, 0.04956191, 0.96699608, 0.76370574, 0.8860385 ,
#        1.608899  , 0.62701782, 0.8934028 , 1.074257  , 0.76728801,
#        0.08954166, 0.41438269, 2.27572759, 0.58737259, 1.17820793])

# %%
fig, ax = plt.subplots()
_= plt.hist(x, color='lightgray')

# %%
xbar = x.mean()
xbar
# Out:
# np.float64(0.7848399608405058)

# %%
fig, ax = plt.subplots()
plt.axvline(x = x.mean(), color='orange')
_= plt.hist(x, color='lightgray')

# %%
np.median(x)
# Out:
# np.float64(0.673589539066034)

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange')
plt.axvline(x = np.median(x), color='green')
_= plt.hist(x, color='lightgray')

# %%
x.var()
# Out:
# np.float64(0.3554390565714122)

# %%
x.var()**(1/2)
# Out:
# np.float64(0.596187098628788)

# %%
sigma = x.std()
sigma
# Out:
# np.float64(0.596187098628788)

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='orange')
plt.axvline(x = xbar+sigma, color='olivedrab')
plt.axvline(x = xbar-sigma, color='olivedrab')
_= plt.hist(x, color='lightgray')

# %%
sigma/(x.size)**(1/2)
# Out:
# np.float64(0.018853091432744187)

# %%
st.sem(x)
# Out:
# np.float64(0.018862525054266596)

# %%
st.sem(x,ddof=0)
# Out:
# np.float64(0.018853091432744187)

# %%
x = np.random.normal(size=1000)

# %%
sns.set_style('ticks')

# %%
_= sns.displot(x,kde=True)

# %%
x.mean()
# Out:
# np.float64(-0.0492736394028694)

# %%
x.std()
# Out:
# np.float64(0.9918838990848033)

# %%
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([-2.0362205 , -1.17696211,  0.85958487,  0.39330705,  2.07506504,
#        -0.11081256,  0.29156368,  0.02731338,  0.75951489, -1.18305618])

# %%
x_sample.mean()
# Out:
# np.float64(-0.010070245492244001)

# %%
def sample_mean_calculator(input_dist, sample_size, n_simples):
  sample_means = []
  for i in range (n_samples):
    sample = np.random.choice(input_dist, size=sample_size, replace=False)
    sample_means.append(sample.mean())
  return sample_means

# %%
def sample_mean_calculator(input_dist, sample_size, n_simples):
  sample_means = []
  for i in range (n_simples):
    sample = np.random.choice(input_dist, size=sample_size, replace=False)
    sample_means.append(sample.mean())
  return sample_means

sns.displot(sample_mean_calculator(x, 10, 1000), color = 'green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
s = st.skewnorm.rvs(10, size= 1000)
_ = sns.displot(s, kde=True)

# %%
_ = sns.displot(sample_mean_calculator(s, 10, 1000), color = 'green', kde=True)

# %%
m = np.concatenate((np.random.normal(size = 5000), np.random.normal(loc=4.0, size = 5000),np.random.normal(loc=8.0, size = 5000)))

# %%
_ = sns.displot(m, kde=True)

# %%
u = np.random.uniform(size=10000)

# %%
_ = sns.displot(u)

# %%
x_i = 85
mu = 60
sigma = 10

# %%
x = np.random.normal(mu,sigma, 10000)

# %%
sns.displot(x, color='gray')
ax.set_xlim(0,100)
plt.axvline(mu, color='orange')
for v in [-3, -2, -1, 1, 2 , 3]:
  plt.axvline(mu+v*sigma, color='olivedrab')
_ = plt.axvline(x_i, color='green')

# %%
z = (x_i -mu)/sigma
z
# Out:
# 2.5

# %%
len(np.where(x>85)[0])
# Out:
# 53

# %%
100*53/10000
# Out:
# 0.53

# %%
np.percentile(x,99)
# Out:
# np.float64(83.07802652839904)

# %%
p_below = st.norm.cdf(-2.5)
p_below
# Out:
# np.float64(0.006209665325776132)

# %%
p_below*10000
# Out:
# np.float64(62.096653257761325)

# %%
y = np.random.normal(mu,sigma, 10000)

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu-2.5*sigma, color='blue')

# %%
st.norm.cdf(2.5)
p_above = 1-st.norm.cdf(2.5)
p_above
# Out:
# np.float64(0.006209665325776159)

# %%
p_above*10000
# Out:
# np.float64(62.09665325776159)

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu+2.5*sigma, color='blue')

# %%
p_outside = p_below + p_above
p_outside
# Out:
# np.float64(0.01241933065155229)

# %%
p_outside*10000
# Out:
# np.float64(124.1933065155229)

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu-2.5*sigma, color='blue')
_ = plt.axvline(mu+2.5*sigma, color='blue')

# %%
st.norm.ppf(.025)
# Out:
# np.float64(-1.9599639845400545)

# %%
st.norm.ppf(.975)
# Out:
# np.float64(1.959963984540054)

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu+1.96*sigma, color='darkred')
_ = plt.axvline(mu-1.96*sigma, color='darkred')

# %%
st.norm.ppf(.005)
# Out:
# np.float64(-2.575829303548901)

# %%
st.norm.ppf(.995)
# Out:
# np.float64(2.5758293035489004)

# %%
sns. displot(y, color='gray')
_ = plt.axvline(mu+1.96*sigma, color='darkred')
_ = plt.axvline(mu-1.96*sigma, color='darkred')
_ = plt.axvline(mu+2.58*sigma, color='black')
_ = plt.axvline(mu-2.58*sigma, color='black')

# %%
data = np.array([85,90,78,92,88,78,95,69,82,80])
mean_val = np.mean(data)
std_val = np.std(data)
print(f'mean: {mean_val:.2f}')
print(f'standard deviation: {std_val:.2f}')
# Out:
# mean: 83.70
# standard deviation: 7.44

# %%
import scipy.stats as stats
z_scores = stats.zscore(data)
print (f'Z-scores{z_scores}')
z_input = 1.5
x_val = mean_val +(z_input * std_val)
print(f'Raw score (x for z = 1.5: {x_val:.2f})')
# Out:
# Z-scores[ 0.17464223  0.84634313 -0.76573902  1.11502349  0.57766277 -0.76573902
#   1.51804403 -1.97480064 -0.22837831 -0.49705866]
# Raw score (x for z = 1.5: 94.87)

# %%
from numpy.random import normal
normal_dist = np.random.normal(50, 10, 1000)
skewed_dist = stats.skewnorm.rvs(a = 10, loc = 50, scale = 10, size = 1000)

plt.figure(figsize = (10, 5))
plt.hist(normal_dist, bins = 30, alpha = 0.5, label = 'Normal Distribution', color = 'skyblue')
plt.hist(skewed_dist, bins = 30, alpha = 0.5, label = 'Right Skewed', color= 'salmon')
plt.title("visualizing skewness")
plt.legend()
plt.show()
